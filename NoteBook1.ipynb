# %%
# %pip install pandas
# %pip install scikit-learn
# %pip install plotly[express]
# Out:
# Requirement already satisfied: pandas in .\.venv\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in .\.venv\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in .\.venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in .\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly[express]
#   Downloading plotly-6.6.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly[express])
#   Downloading narwhals-2.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in .\.venv\Lib\site-packages (from plotly[express]) (26.0)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (from plotly[express]) (2.4.3)
# Downloading plotly-6.6.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 508.6 kB/s eta 0:00:19
#    -- ------------------------------------- 0.5/9.9 MB 508.6 kB/s eta 0:00:19
#    --- ------------------------------------ 0.8/9.9 MB 555.0 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.0/9.9 MB 609.8 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.0/9.9 MB 609.8 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.0/9.9 MB 609.8 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.9 MB 598.8 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/9.9 MB 598.8 kB/s eta 0:00:15
#    ------ --------------------------------- 1.6/9.9 MB 571.2 kB/s eta 0:00:15
#    ------- -------------------------------- 1.8/9.9 MB 614.3 kB/s eta 0:00:14
#    -------- ------------------------------- 2.1/9.9 MB 670.7 kB/s eta 0:00:12
#    --------- ------------------------------ 2.4/9.9 MB 725.5 kB/s eta 0:00:11
#    ---------- ----------------------------- 2.6/9.9 MB 778.2 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.9 MB 778.2 kB/s eta 0:00:10
#    ----------- ---------------------------- 2.9/9.9 MB 736.4 kB/s eta 0:00:10
#    ------------ --------------------------- 3.1/9.9 MB 759.5 kB/s eta 0:00:09
#    ------------ --------------------------- 3.1/9.9 MB 759.5 kB/s eta 0:00:09
#    ------------- -------------------------- 3.4/9.9 MB 746.7 kB/s eta 0:00:09
#    -------------- ------------------------- 3.7/9.9 MB 776.5 kB/s eta 0:00:09
#    --------------- ------------------------ 3.9/9.9 MB 793.3 kB/s eta 0:00:08
#    --------------- ------------------------ 3.9/9.9 MB 793.3 kB/s eta 0:00:08
#    ---------------- ----------------------- 4.2/9.9 MB 788.1 kB/s eta 0:00:08
#    ----------------- ---------------------- 4.5/9.9 MB 811.5 kB/s eta 0:00:07
#    ------------------- -------------------- 4.7/9.9 MB 827.4 kB/s eta 0:00:07
#    -------------------- ------------------- 5.0/9.9 MB 845.7 kB/s eta 0:00:06
#    --------------------- ------------------ 5.2/9.9 MB 868.4 kB/s eta 0:00:06
#    ---------------------- ----------------- 5.5/9.9 MB 870.4 kB/s eta 0:00:06
#    ----------------------- ---------------- 5.8/9.9 MB 875.8 kB/s eta 0:00:05
#    ------------------------ --------------- 6.0/9.9 MB 896.7 kB/s eta 0:00:05
#    ------------------------- -------------- 6.3/9.9 MB 909.6 kB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 923.4 kB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 923.4 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 897.0 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 897.0 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 877.8 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 877.8 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 877.8 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.1/9.9 MB 877.8 kB/s eta 0:00:04
#    ------------------------------ --------- 7.6/9.9 MB 860.0 kB/s eta 0:00:03
#    ------------------------------ --------- 7.6/9.9 MB 860.0 kB/s eta 0:00:03
#    ------------------------------- -------- 7.9/9.9 MB 848.5 kB/s eta 0:00:03
#    -------------------------------- ------- 8.1/9.9 MB 859.6 kB/s eta 0:00:03
#    -------------------------------- ------- 8.1/9.9 MB 859.6 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/9.9 MB 849.9 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/9.9 MB 853.2 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/9.9 MB 856.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/9.9 MB 856.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/9.9 MB 856.9 kB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 840.1 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 859.5 kB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 868.5 kB/s  0:00:11
# Downloading narwhals-2.18.1-py3-none-any.whl (444 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.18.1 plotly-6.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import plotly.express as px

# %%
data = pd.read_csv('loan_approval_data.csv')
data.head()
# Out:
#       id   age  income home_ownership  emplyment_length      loan_intent  \
# 0  35437  21.0   12000            OWN                 0        EDUCATION
# 1  53756  21.0   13200            OWN                 2        EDUCATION
# 2  42205  23.0    9600           RENT                 5          MEDICAL
# 3  19180  40.0  182004           RENT                 3        EDUCATION
# 4  28072  40.0   90000       MORTGAGE                 3  HOMEIMPROVEMENT
#
#    loan_amount  loan_interest_rate  loan_income_ratio payment_default_on_file  \
# 0        15000                6.99               0.12                       N
# 1        25000               16.77               0.19                       Y
# 2        30000               12.42               0.31                       N
# 3        35000                8.00               0.19                       N
# 4        35000               12.42               0.39                       N
#
#    credit_history_length  loan_approval_status  max_allowed_loan
# 0                      4                     0          -2426900
# 1                      3                     0           -111739
# 2                      3                     0            -89000
# 3                     11                     0             35000
# 4                     14                     0             35000

# %%
data.shape
# Out:
# (58645, 13)

# %%
list(data.columns)
# Out:
# ['id',
#  'age',
#  'income',
#  'home_ownership',
#  'emplyment_length',
#  'loan_intent',
#  'loan_amount',
#  'loan_interest_rate',
#  'loan_income_ratio',
#  'payment_default_on_file',
#  'credit_history_length',
#  'loan_approval_status',
#  'max_allowed_loan']

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       58645 non-null  int64
#  1   age                      58639 non-null  float64
#  2   income                   58645 non-null  int64
#  3   home_ownership           58645 non-null  str
#  4   emplyment_length         58645 non-null  int64
#  5   loan_intent              58645 non-null  str
#  6   loan_amount              58645 non-null  int64
#  7   loan_interest_rate       58634 non-null  float64
#  8   loan_income_ratio        58645 non-null  float64
#  9   payment_default_on_file  58640 non-null  str
#  10  credit_history_length    58645 non-null  int64
#  11  loan_approval_status     58645 non-null  int64
#  12  max_allowed_loan         58645 non-null  int64
# dtypes: float64(3), int64(7), str(3)
# memory usage: 5.8 MB

# %%
data.describe()
# Out:
#                  id           age        income  emplyment_length  \
# count  58645.000000  58639.000000  5.864500e+04      58645.000000
# mean   29322.000000     27.550913  6.404617e+04          4.703487
# std    16929.497605      6.033217  3.793111e+04          4.004982
# min        0.000000     20.000000  4.200000e+03          0.000000
# 25%    14661.000000     23.000000  4.200000e+04          2.000000
# 50%    29322.000000     26.000000  5.800000e+04          4.000000
# 75%    43983.000000     30.000000  7.560000e+04          7.000000
# max    58644.000000    123.000000  1.900000e+06        150.000000
#
#         loan_amount  loan_interest_rate  loan_income_ratio  \
# count  58645.000000        58634.000000       58645.000000
# mean    9217.556518           10.677526           0.159238
# std     5563.807384            3.036034           0.091692
# min      500.000000          -11.140000           0.000000
# 25%     5000.000000            7.880000           0.090000
# 50%     8000.000000           10.750000           0.140000
# 75%    12000.000000           12.990000           0.210000
# max    35000.000000           23.220000           0.830000
#
#        credit_history_length  loan_approval_status  max_allowed_loan
# count           58645.000000          58645.000000      5.864500e+04
# mean                5.813556              0.142382      6.975472e+04
# std                 4.029196              0.349445      6.175091e+04
# min                 2.000000              0.000000     -2.426900e+06
# 25%                 3.000000              0.000000      3.800300e+04
# 50%                 4.000000              0.000000      6.239200e+04
# 75%                 8.000000              0.000000      9.271600e+04
# max                30.000000              1.000000      2.638778e+06

# %%
data.describe().transpose()
# Out:
#                          count          mean           std         min  \
# id                     58645.0  29322.000000  16929.497605        0.00
# age                    58639.0     27.550913      6.033217       20.00
# income                 58645.0  64046.172871  37931.106978     4200.00
# emplyment_length       58645.0      4.703487      4.004982        0.00
# loan_amount            58645.0   9217.556518   5563.807384      500.00
# loan_interest_rate     58634.0     10.677526      3.036034      -11.14
# loan_income_ratio      58645.0      0.159238      0.091692        0.00
# credit_history_length  58645.0      5.813556      4.029196        2.00
# loan_approval_status   58645.0      0.142382      0.349445        0.00
# max_allowed_loan       58645.0  69754.717828  61750.913820 -2426900.00
#
#                             25%       50%       75%         max
# id                     14661.00  29322.00  43983.00    58644.00
# age                       23.00     26.00     30.00      123.00
# income                 42000.00  58000.00  75600.00  1900000.00
# emplyment_length           2.00      4.00      7.00      150.00
# loan_amount             5000.00   8000.00  12000.00    35000.00
# loan_interest_rate         7.88     10.75     12.99       23.22
# loan_income_ratio          0.09      0.14      0.21        0.83
# credit_history_length      3.00      4.00      8.00       30.00
# loan_approval_status       0.00      0.00      0.00        1.00
# max_allowed_loan       38003.00  62392.00  92716.00  2638778.00

# %%
df = data.drop(columns=(['id']))
df.rename({
    "emplyment_length": "employment_length"
}, axis=1, inplace=True)
df.head()
# Out:
#     age  income home_ownership  employment_length      loan_intent  \
# 0  21.0   12000            OWN                  0        EDUCATION
# 1  21.0   13200            OWN                  2        EDUCATION
# 2  23.0    9600           RENT                  5          MEDICAL
# 3  40.0  182004           RENT                  3        EDUCATION
# 4  40.0   90000       MORTGAGE                  3  HOMEIMPROVEMENT
#
#    loan_amount  loan_interest_rate  loan_income_ratio payment_default_on_file  \
# 0        15000                6.99               0.12                       N
# 1        25000               16.77               0.19                       Y
# 2        30000               12.42               0.31                       N
# 3        35000                8.00               0.19                       N
# 4        35000               12.42               0.39                       N
#
#    credit_history_length  loan_approval_status  max_allowed_loan
# 0                      4                     0          -2426900
# 1                      3                     0           -111739
# 2                      3                     0            -89000
# 3                     11                     0             35000
# 4                     14                     0             35000

# %%
labelEn = LabelEncoder()

categorical_cols = ['home_ownership', 'loan_intent', 'payment_default_on_file']

for col in categorical_cols:
  df[col] = labelEn.fit_transform(df[col])

df.head()
# Out:
#     age  income  home_ownership  employment_length  loan_intent  loan_amount  \
# 0  21.0   12000               2                  0            1        15000
# 1  21.0   13200               2                  2            1        25000
# 2  23.0    9600               3                  5            3        30000
# 3  40.0  182004               3                  3            1        35000
# 4  40.0   90000               0                  3            2        35000
#
#    loan_interest_rate  loan_income_ratio  payment_default_on_file  \
# 0                6.99               0.12                        0
# 1               16.77               0.19                        1
# 2               12.42               0.31                        0
# 3                8.00               0.19                        0
# 4               12.42               0.39                        0
#
#    credit_history_length  loan_approval_status  max_allowed_loan
# 0                      4                     0          -2426900
# 1                      3                     0           -111739
# 2                      3                     0            -89000
# 3                     11                     0             35000
# 4                     14                     0             35000
